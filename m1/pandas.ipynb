# %%
import pandas as pd

# %%
es = pd.Series()

# %%
es
# Out:
# Series([], dtype: object)

# %%
es.ndim
# Out:
# 1

# %%
es.index
# Out:
# RangeIndex(start=0, stop=0, step=1)

# %%
es.values
# Out:
# array([], dtype=object)

# %%
es.name

# %%
type(es.name)
# Out:
# NoneType

# %%
ms = pd.Series(data = [1, 2, 3, 4])

# %%
ms
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
type(ms)
# Out:
# pandas.core.series.Series

# %%
ms.dtype
# Out:
# dtype('int64')

# %%
ms.ndim
# Out:
# 1

# %%
ms.shape
# Out:
# (4,)

# %%
ms.size
# Out:
# 4

# %%
ms.values
# Out:
# array([1, 2, 3, 4])

# %%
ns = pd.Series(data = ['Ashok', 'Kumar', 18, 183], index=['First Name', 'Last Name', 'Age', 'Height'], name = 'Student Info')

# %%
ns
# Out:
# First Name    Ashok
# Last Name     Kumar
# Age              18
# Height          183
# Name: Student Info, dtype: object

# %%
ns.name
# Out:
# 'Student Info'

# %%
ns.index
# Out:
# Index(['First Name', 'Last Name', 'Age', 'Height'], dtype='object')

# %%
my_dict = {'A': 'Viplav Soni', 'B': 'Ravi Gupta', 'C': 'Harsh Gujral', 'D': 'Vivek S' }
ds = pd.Series(data = my_dict, index=['indexTy', 'Name'], name = 'Stand up comics')

# %%
ds
# Out:
# indexTy    NaN
# Name       NaN
# Name: Stand up comics, dtype: object
