# %%
import pandas as pd

# %%
df_empty = pd.DataFrame()

# %%
type(df_empty)
# Out:
# pandas.core.frame.DataFrame

# %%
df_empty.shape
# Out:
# (0, 0)

# %%
df_empty.size
# Out:
# 0

# %%
df_empty.ndim
# Out:
# 2

# %%
df_empty.index
# Out:
# RangeIndex(start=0, stop=0, step=1)

# %%
df_empty.columns
# Out:
# RangeIndex(start=0, stop=0, step=1)

# %%
df_empty.values
# Out:
# array([], shape=(0, 0), dtype=float64)

# %%
data = {
    'Name': ['Alice', 'Bob', 'Chandni', 'Dawood'],
    'Age': [25, 30, 18, 22],
    'City': ['Mumbai', 'Kolkata', 'Delhi', 'Bengaluru']
}
df1 = pd.DataFrame(data)

# %%
df1.shape
# Out:
# (4, 3)

# %%
df1
# Out:
#       Name  Age       City
# 0    Alice   25     Mumbai
# 1      Bob   30    Kolkata
# 2  Chandni   18      Delhi
# 3   Dawood   22  Bengaluru

# %%
df1.ndim
# Out:
# 2

# %%
df1.values
# Out:
# array([['Alice', 25, 'Mumbai'],
#        ['Bob', 30, 'Kolkata'],
#        ['Chandni', 18, 'Delhi'],
#        ['Dawood', 22, 'Bengaluru']], dtype=object)

# %%
df1.dtypes
# Out:
# Name    object
# Age      int64
# City    object
# dtype: object

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
indian_startup = pd.read_csv('indian_startups.csv', index_col='Company')

# %%
indian_startup.index
# Out:
# Index(['Urban Company', 'Classplus', 'Paytm', 'Apna', 'Razorpay', 'UpGrad',
#        'Delhivery', '1mg', 'BigBasket', 'GoMechanic',
#        ...
#        'GirnarSoft', 'Meesho', 'Lenskart', 'Udaan', 'Zolve', 'SafexPay',
#        'Pariksha', 'Fyllo', 'CredFlow', 'HalaPlay Technologies'],
#       dtype='object', name='Company', length=300)

# %%
indian_startup = pd.read_csv('indian_startups.csv', nrows=6)

# %%
indian_startup
# Out:
#          Company       City  Starting Year  \
# 0  Urban Company    Gurgaon           2014
# 1      Classplus      Noida           2018
# 2          Paytm      Noida           2010
# 3           Apna     Mumbai           2019
# 4       Razorpay  Bengaluru           2014
# 5         UpGrad     Mumbai           2015
#
#                                             Founders  \
# 0  Abhiraj Singh Bhal, Raghav Chandra, Varun Khaitan
# 1  Bhaswat Agarwal, Bikash Dash, Mukul Rustagi, N...
# 2                Akshay Khanna, Vijay Shekhar Sharma
# 3                                      Nirmit Parikh
# 4                     Harshil Mathur, Shashank Kumar
# 5  Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
#
#                                           Industries  \
# 0  Apps, Home Services, Marketplace, Service Indu...
# 1  B2B, E-Learning, EdTech, Education, Mobile App...
# 2  E-Commerce, Finance, Financial Services, Inter...
# 3  Employment, Human Resources, Recruiting, Staff...
# ...

# %%
indian_startup
# Out:
#                    Company       City  Starting Year  \
# 0            Urban Company    Gurgaon           2014
# 1                Classplus      Noida           2018
# 2                    Paytm      Noida           2010
# 3                     Apna     Mumbai           2019
# 4                 Razorpay  Bengaluru           2014
# ..                     ...        ...            ...
# 295               SafexPay      Thane           2017
# 296               Pariksha       Pune           2015
# 297                  Fyllo  Bengaluru           2019
# 298               CredFlow  New Delhi           2019
# 299  HalaPlay Technologies  Bengaluru           2016
#
#                                               Founders  \
# 0    Abhiraj Singh Bhal, Raghav Chandra, Varun Khaitan
# 1    Bhaswat Agarwal, Bikash Dash, Mukul Rustagi, N...
# 2                  Akshay Khanna, Vijay Shekhar Sharma
# 3                                        Nirmit Parikh
# ...

# %%
indian_startup.shape
# Out:
# (300, 10)

# %%
indian_startup.index
# Out:
# RangeIndex(start=0, stop=300, step=1)

# %%
indian_startup.ndim
# Out:
# 2

# %%
indian_startup.size
# Out:
# 3000

# %%
indian_startup.
